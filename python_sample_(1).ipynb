# %% [markdown]
# <a href="https://colab.research.google.com/github/promahaque2003-commits/Milestone-1/blob/main/python_sample_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sampling Assignment
# Implementing Probability Sampling Methods in Python
#
# ## Instructions
# Upload your dataset (minimum 200 rows), then complete all parts A–F.

# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv('insurance (2).csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Part A — Setup
# - Report dataset size (rows, columns)

# %%
print("insurance (2) size:", df.shape)
# Out:
# insurance (2) size: (1338, 7)

# %% [markdown]
# ## Part B — Simple Random Sampling

# %%
sample_size = 50
srs = df.sample(n=sample_size, random_state=42)
print(srs.head())
print("Population mean:", df['age'].mean())
print("Sample mean:", srs['age'].mean())
# Out:
#       age     sex     bmi  children smoker     region      charges
# 764    45  female  25.175         2     no  northeast   9095.06825
# 887    36  female  30.020         0     no  northwest   5272.17580
# 890    64  female  26.885         0    yes  northwest  29330.98315
# 1293   46    male  25.745         3     no  northwest   9301.89355
# 259    19    male  31.920         0    yes  northwest  33750.29180
# Population mean: 39.20702541106129
# Sample mean: 38.92

# %% [markdown]
# ## Part C — Systematic Sampling

# %%
n = 50
k = len(df) // n
start = np.random.randint(0, k)
sys_sample = df.iloc[start::k][:n]
sys_sample.head()
# Out:
#      age     sex     bmi  children smoker     region      charges
# 11    62  female  26.290         0    yes  southeast  27808.72510
# 37    26    male  20.800         0     no  southwest   2302.30000
# 63    28  female  25.935         1     no  northwest   4133.64165
# 89    55  female  26.980         0     no  northwest  11082.57720
# 115   60    male  28.595         0     no  northeast  30259.99556

# %% [markdown]
# ## Part D — Stratified Sampling

# %%
strata_col = "age"  # your column
sample_size = 50

# proportional fraction for each group
frac = sample_size / len(df)

# stratified sample
stratified_sample = df.groupby(strata_col, group_keys=False).sample(frac=frac, random_state=42)

stratified_sample.head()
# Out:
#       age     sex     bmi  children smoker     region     charges
# 442    18    male  43.010         0     no  southeast  1149.39590
# 1      18    male  33.770         1     no  southeast  1725.55230
# 940    18    male  23.210         0     no  southeast  1121.87390
# 960    19  female  39.615         1     no  northwest  2730.10785
# 1129   19  female  18.600         0     no  southwest  1728.89700

# %% [markdown]
# ## Part E — Cluster Sampling

# %%
df['cluster_id'] = df.index // (len(df)//10)  # 10 clusters
selected_clusters = np.random.choice(df['cluster_id'].unique(), size=2, replace=False)
cluster_sample = df[df['cluster_id'].isin(selected_clusters)]
print("Selected clusters:", selected_clusters)
cluster_sample.head()
# Out:
# Selected clusters: [ 2 10]
#      age     sex     bmi  children smoker     region      charges  cluster_id
# 266   40    male  19.800         1    yes  southeast  17179.52200           2
# 267   59  female  32.395         3     no  northeast  14590.63205           2
# 268   45    male  30.200         1     no  southwest   7441.05300           2
# 269   49    male  25.840         1     no  northeast   9282.48060           2
# 270   18    male  29.370         1     no  southeast   1719.43630           2

# %% [markdown]
# ## Part F — Comparison & Reflection
# Compare sample means vs population mean, then write your reflection.

# %% [markdown]
# The sample mean and the population mean are concodent to each other , that means the data that we have used in this milestone is accurate. As the difference is very low between the two means. In conclusion the dataset is reliable to use.
