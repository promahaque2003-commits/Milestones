# %% [markdown]
# <a href="https://colab.research.google.com/github/promahaque2003-commits/Milestones/blob/main/milestone5(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Milestone 5 – Probability
# This notebook contains sample code for each section of Milestone 5.

# %% [markdown]
# ## Section A: Setup & Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load your dataset
# Replace with the actual filename
df = pd.read_csv('insurance (2).csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Section B: Treat Dataset as Sample Space

# %%
N = len(df)
print('Total observations:', N)
# Out:
# Total observations: 1338

# %% [markdown]
# ## Section C: Task 1 – Defining Events

# %%
# Example event definitions (change column names as needed)
A = df[df['age'] > 30]
B = df[df['smoker'] == 'yes']
C = df[(df['age'] >= 20) & (df['age'] <= 40)]

print('Event A size:', len(A))
print('Event B size:', len(B))
print('Event C size:', len(C))
# Out:
# Event A size: 894
# Event B size: 274
# Event C size: 564

# %% [markdown]
# ## Section D: Task 2 – Calculating Basic Probability

# %%
P_A = len(A) / N
P_B = len(B) / N
P_C = len(C) / N

print('P(A) =', P_A)
print('P(B) =', P_B)
print('P(C) =', P_C)
# Out:
# P(A) = 0.6681614349775785
# P(B) = 0.20478325859491778
# P(C) = 0.42152466367713004

# %% [markdown]
# ## Section E: Task 3 – Combined Events

# %%
A_int_B = df[(df['age'] > 30) & (df['smoker'] == 'yes')]
P_A_int_B = len(A_int_B) / N
print('P(A ∩ B) =', P_A_int_B)

A_union_B = df[(df['age'] > 30) | (df['smoker'] == 'yes')]
P_A_union_B = len(A_union_B) / N
print('P(A ∪ B) =', P_A_union_B)

A_comp = df[df['age'] <= 30]
P_A_comp = len(A_comp) / N
print('P(Aᶜ) =', P_A_comp)

rule_value = P_A + P_B - P_A_int_B
print('Rule Verification (P(A) + P(B) - P(A ∩ B)):', rule_value)
print('Actual P(A ∪ B):', P_A_union_B)
# Out:
# P(A ∩ B) = 0.13378176382660686
# P(A ∪ B) = 0.7391629297458894
# P(Aᶜ) = 0.33183856502242154
# Rule Verification (P(A) + P(B) - P(A ∩ B)): 0.7391629297458894
# Actual P(A ∪ B): 0.7391629297458894

# %% [markdown]
# ## Section F: Visualization

# %%
counts = [len(A), len(A_comp)]
labels = ['A: age > 30', 'Aᶜ: age ≤ 30']

plt.bar(labels, counts)
plt.title('Event A and Complement Frequency')
plt.ylabel('Count')
plt.show()

# %%
df['region'].value_counts().plot(kind='bar')
plt.title('Region Frequency')
plt.ylabel('Count')
plt.xlabel('Region')
plt.show()

# %% [markdown]
# ## Section G: Summary (Write your reflection here)
